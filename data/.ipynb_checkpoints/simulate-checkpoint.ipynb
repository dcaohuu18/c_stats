# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import random
from datetime import datetime
from faker import Faker

# %% [markdown]
# **Steps:**
# 1. [x] Decide the variables
# 2. [ ] Fake data for one student
# 3. [ ] Fake data for one class
# 4. [ ] Fake data for multiple classes
# 5. [ ] Fake data for multiple terms

# %% [markdown]
# ---
# ### Decide the variables:

# %%
# Basic_Info:
    # id 
    # f_name
    # l_name
    # gender
    # race
    # birth_dt
    # address
    # email
    
# Academic_Performance:
    # Grades of quizzes, tests, home assignments
    # Attendance
    # Number of on-time, late, and missed assignments
    # Number of accesses to LMS
    # Average time spent on LMS
    # Messages on LMS (for example, number of questions and responses on the discussion forum)

# %% [markdown]
# ---
# ### Fake data for one student:

# %%
def ewma_predict(series):
    print()

# %%
def fake_student_grades(grade1_mu, grade1_std, n_tests): # n_home_ex
    grade1 = int(round(random.gauss(grade1_mu, grade1_std)))
    grade1 = grade1 if grade1 <= 100 else 100 # can't be > 100
    grade_series = pd.Series([grade1])
    
    var_std = random.uniform(2, 5)
    print(var_std)
    
    for t in range(n_tests-1):
        variation = random.gauss(0, var_std)
        # shock?
        next_grade = grade_series.ewm(span=3).mean().iloc[-1] + variation
        next_grade = next_grade if next_grade <= 100 else 100 # can't be > 100
        next_grade = pd.Series(next_grade).round()
    
        grade_series = grade_series.append(next_grade)
        # need to verify how ewm works
        
    return grade_series

fake_student_grades(78, 7, 10)
# Out:
# 2.0733007867060356
# 0    73.0
# 0    74.0
# 0    70.0
# 0    70.0
# 0    74.0
# 0    73.0
# 0    69.0
# 0    71.0
# 0    71.0
# 0    75.0
# dtype: float64

# %%
class_size = 30
quiz1_grades = [] 

for i in range(class_size):
    quiz1_grades.append(int(round(random.gauss(mu=70, sigma=10))))
    
plt.hist(quiz1_grades)
# Out:
# (array([3., 1., 2., 3., 4., 5., 6., 2., 3., 1.]),
#  array([51. , 54.6, 58.2, 61.8, 65.4, 69. , 72.6, 76.2, 79.8, 83.4, 87. ]),
#  <a list of 10 Patch objects>)

# %%
def fake_student_attendance(mean_grade):
    print()

# %%
pd.Series([1, 2, 2, 3, 4, 5]).ewm(span=2).mean()
# Out:
# 0    1.000000
# 1    1.750000
# 2    1.923077
# 3    2.650000
# 4    3.553719
# 5    4.519231
# dtype: float64

# %% [markdown]
# ---
# ### Fake data for one class:

# %%
# assume there's no relationship bw basic info & academic performance
def fake_class_basic_info(class_size):
    columns = ['id', 'f_name', 'l_name', 'gender', 'race', 'birth_dt', 'address', 'email']
    info_df = pd.DataFrame(columns=columns)
    
    possible_races = ['White', 'Black', 'Native', 'Asian', 'Pacific Islander', 'Mixed']
    race_prob = [0.763, 0.134, 0.013, 0.059, 0.002, 0.029]
    
    # Faker.seed(1234) # for producing the same results 
    fake = Faker()
    
    for s in range(class_size):
        student = {
            'id': fake.ssn(),
            'l_name': fake.last_name(),
            'gender': random.choice(['M', 'F']),
            'race': np.random.choice(possible_races, replace=True, p=race_prob),
            'birth_dt': fake.date_between_dates(date_start=datetime(1997, 1, 1), 
                                                date_end=datetime(2001, 12, 31)),
            'address': fake.address(),
            'email': fake.free_email()
        }    
        student['f_name'] = fake.first_name_male() if student['gender']=='M' else fake.first_name_female()
        
        info_df = info_df.append(student, ignore_index=True)
    
    return info_df

fake_class_basic_info(30)
# Out:
#              id       f_name     l_name gender   race    birth_dt  \
# 0   561-74-1331        Renee     Foster      F  White  2001-12-30
# 1   323-36-6106      William       Kirk      M  White  1997-02-03
# 2   405-04-5561       Brenda      Moore      F  White  2000-05-26
# 3   392-71-6994         Kyle       Soto      M  White  1997-03-30
# 4   102-67-0211      Patrick     Porter      M  White  1999-05-17
# 5   065-78-1255      Michael      Payne      M  White  2001-02-15
# 6   458-99-0863         Drew   Mcintyre      M  Black  1999-02-01
# 7   702-43-6504      Crystal  Rasmussen      F  White  2000-07-30
# 8   685-41-2249       Manuel    Rodgers      M  White  1999-03-25
# 9   793-08-1218      Jessica      Baker      F  White  1999-09-25
# 10  405-89-4447         Paul       Ross      M  White  1998-04-17
# 11  854-38-5483       Shelby   Gonzales      F  White  2001-07-10
# 12  270-74-4004     Nicholas     Martin      M  White  2001-07-03
# 13  718-01-9447        Terri      Kirby      F  White  1997-07-30
# 14  760-94-6978       Robert      Lopez      M  Black  1998-03-30
# 15  776-74-7384        Chris      Lopez      M  Black  1998-03-18
# 16  500-64-4886     Margaret     Rivera      F  White  1999-07-16
# 17  611-35-0314        James     Garcia      M  White  2000-07-18
# 18  672-19-9019     Caroline       Ryan      F  White  1999-04-16
# 19  354-38-5178         Marc    Kennedy      M  White  1997-03-25
# 20  432-08-3828         Sean    Bonilla      M  White  1997-09-22
# 21  560-33-1291      Michael    Stevens      M  White  2001-01-10
# 22  865-08-7981       Angela   Hamilton      F  White  1998-05-24
# 23  488-23-6046        Malik    Russell      M  White  2000-09-07
# 24  652-10-1334      Michael   Peterson      M  White  2001-03-27
# 25  264-96-2669       Thomas       Kerr      M  White  2000-11-19
# 26  806-09-2523       Kendra     Harris      F  Black  1998-10-15
# 27  130-19-9521         Troy   Campbell      M  Black  1997-11-29
# 28  081-05-7927  Christopher   Martinez      M  Asian  2001-04-04
# 29  775-18-2287     Victoria     Thomas      F  Black  1999-07-21
#
#                                               address  \
# 0    0185 Fischer Ville Apt. 458\nPort Chad, AL 16993
# 1              190 Martin Ridge\nVargasfurt, DE 07402
# 2           85792 Hawkins Trail\nYoungmouth, FL 99569
